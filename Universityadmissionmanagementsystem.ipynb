# %%
class University:
    def __init__(self):
        from colorama import Fore,Back,Style
        print(Fore.RED,Back.WHITE,Style.BRIGHT,"WELCOME TO VIVEKANAND GLOBAL UNIVERSITY")
        print("Here you can do Following: ")
        l=["Graduation","Postgraduation"]
        for i in l:
            print("\n",i)
    def graduation(self):
        courses=["BBA","BCA","Btech","B.COM"]
        fees=[300000,280000,310000,350000]
        years=[3,3,4,3]
        dic={"Courses":courses,"Fees":fees,"Duration_Years":years}
        import pandas as pd
        df=pd.DataFrame(dic)
        print(df)
        m=int(input("enter the position of course you want to enroll in: "))
        d=df["Fees"][m]
        print("Here we have different different activities also, big events,fun games,social clubs")
        a=input("Do you want to see any overview of events that previously occured: Yes/No").lower()
        if (a=="yes"):
            import cv2 as cv
            capture=cv.VideoCapture(r"C:\Users\DELL\Downloads\vgu.mp4")
            while True:
                isTrue,a=capture.read()
                cv.imshow("Video",a)
                if cv.waitKey(60) & 0xff==ord("b"):
                    break
            capture.release()
            cv.destroyAllWindows()
        else:
            print("OK")
        a1=input("Do you want campus tour: Yes/No").lower()
        if a1=="yes":
            import cv2 as cv
            capture=cv.VideoCapture(r"C:\Users\DELL\Downloads\campous tour.mp4")
            while True:
                isTrue,a=capture.read()
                cv.imshow("Video",a)
                if cv.waitKey(60) & 0xff==ord("b"):
                    break
            capture.release()
            cv.destroyAllWindows()
        else:
            print("Ok")
        b=input("enter you want conveyance facilities also:Yes/No ")
        if b=="yes":
            print("We have buses are available for transport\n and the charges are according to kilometers")
            dic={"Charges per Km":[500]}
            import pandas as pd
            df1=pd.DataFrame(dic)
            print(df1)
            b1=int(input("enter your home distance from university: "))
            p=df1["Charges per Km"]
            c=p*b1
        else:
            pass
        h=input("Do you want to join any of the welfare club: Yes/No").lower()
        if h=="yes":
            l=["Food for poor club","clothes for poor club","Free Health checkup club"]
            for i in l:
                print("Here is the list of the club you can join any of them!",i)
            h1=input("Do you want to see images of any of the clubs, how they work socially: Yes/No").lower()
            if h1=="yes":
                a3=input("enter which club images you want to see: ").lower()
                if a3=="food":
                    from PIL import Image
                    img=Image.open(r"C:\Users\DELL\OneDrive\Pictures\food image.jpg")
                    img.show()
                elif a3=="health":
                    from PIL import Image
                    img=Image.open(r"C:\Users\DELL\OneDrive\Pictures\free health.jpg")
                    img.show()
                elif a3=="clothes":
                    from PIL import Image
                    img=Image.open(r"C:\Users\DELL\OneDrive\Pictures\clothing.jpg")
                    img.show()
                else:
                    print("Not Avalable!")
            else:
                print("OK, No worries!")
        else:
            pass
        n=input("enter you want hostel facilities also: Yes/No")
        if n=="yes":
            l=["Ac","Cooler","Fan"]
            charges=[200000,150000,100000]
            d={"Rooms":l,"Charges":charges}
            import pandas as pd
            s=pd.DataFrame(d)
            print(s)
            n1=int(input("enter the position of which type of room you want: "))
            n2=s["Charges"][n1]
            print("Here these are the annual charges of Hostel")
        else:
            print("OK")
        fee=["EMI","Direct Pay"]
        d3={"Payment Method":fee}
        import pandas as pd
        s2=pd.DataFrame(d3)
        print(s2)
        p=int(input("enter the position of how you pay: "))
        if p==0:
            print("Please you can go to finance official to start your emi")
        elif p==1:
            d=df["Fees"][m]
            a4=input("Do you take conveyance facility: Yes/No").lower()
            if a4=="yes":
                p=df1["Charges per Km"][0]
                c=p*b1
                from colorama import Fore,Back,Style
                print(Fore.RED,Back.YELLOW,Style.BRIGHT,"Your Total Tution fees is",d)
                print("Your Total Conveyance charges is",c)
                total=d+c
                print("Your total amount you have to pay is",total)
                import cv2 as cv
                img=cv.imread(r"C:\Users\DELL\OneDrive\Pictures\scanner.jpg")
                cv.imshow("Scanner",img)
                cv.waitKey(0)
            a5=input("enter do you take hostel: Yes/No").lower()
            if a5=="yes":
                n2=s["Charges"][n1]
                d=df["Fees"][m]
                from colorama import Fore,Back,Style
                print(Fore.RED,Back.YELLOW,Style.BRIGHT,"Your Total Tution fees is",d)
                print("Your Hostel Charges are",n2)
                total1=d+n2
                print("Your Total amount you have to pay is",total1)
                import cv2 as cv
                img=cv.imread(r"C:\Users\DELL\OneDrive\Pictures\scanner.jpg")
                cv.imshow("Scanner",img)
                cv.waitKey(0)
                print("Thank You for taking Admission")
        else:
            print("Invalid")
            
    def postgraduation(self):
        courses=["MBA","MCA","Mtech","M.COM"]
        fees=[400000,350000,400000,360000]
        years=[2,2,3,2]
        dic={"Courses":courses,"Fees":fees,"Duration_Years":years}
        import pandas as pd
        df=pd.DataFrame(dic)
        print(df)
        m=int(input("enter the position of course you want to enroll in: "))
        d=df["Fees"][m]
        print("Here we have different different activities also, big events,fun games,social clubs")
        a=input("Do you want to see any overview of events that previously occured: Yes/No").lower()
        if (a=="yes"):
            import cv2 as cv
            capture=cv.VideoCapture(r"C:\Users\DELL\Downloads\vgu.mp4")
            while True:
                isTrue,a=capture.read()
                cv.imshow("Video",a)
                if cv.waitKey(60) & 0xff==ord("b"):
                    break
            capture.release()
            cv.destroyAllWindows()
        else:
            print("OK")
        k1=input("enter do you want to see celebrity event: ").lower()
        if k1=="yes":
            import cv2 as cv
            capture=cv.VideoCapture(r"C:\Users\DELL\Downloads\celebrity.mp4")
            while True:
                isTrue,a=capture.read()
                cv.imshow("Video",a)
                if cv.waitKey(60) & 0xff==ord("b"):
                    break
            capture.release()
            cv.destroyAllWindows()
        else:
            pass
        a1=input("Do you want campus tour: Yes/No").lower()
        if a1=="yes":
            import cv2 as cv
            capture=cv.VideoCapture(r"C:\Users\DELL\Downloads\campous tour.mp4")
            while True:
                isTrue,a=capture.read()
                cv.imshow("Video",a)
                if cv.waitKey(60) & 0xff==ord("b"):
                    break
            capture.release()
            cv.destroyAllWindows()
        else:
            print("Ok")
        b=input("enter you want conveyance facilities also:Yes/No ")
        if b=="yes":
            print("We have buses are available for transport\n and the charges are according to kilometers")
            dic={"Charges per Km":[500]}
            import pandas as pd
            df1=pd.DataFrame(dic)
            print(df1)
            b1=int(input("enter your home distance from university: "))
            p=df1["Charges per Km"]
            c=p*b1
        else:
            pass
        h=input("Do you want to join any of the welfare club: Yes/No").lower()
        if h=="yes":
            l=["Food for poor club","clothes for poor club","Free Health checkup club"]
            for i in l:
                print("Here is the list of the club you can join any of them!",i)
            h1=input("Do you want to see images of any of the clubs, how they work socially: Yes/No").lower()
            if h1=="yes":
                a3=input("enter which club images you want to see: ").lower()
                if a3=="food":
                    from PIL import Image
                    img=Image.open(r"C:\Users\DELL\OneDrive\Pictures\food image.jpg")
                    img.show()
                elif a3=="health":
                    from PIL import Image
                    img=Image.open(r"C:\Users\DELL\OneDrive\Pictures\free health.jpg")
                    img.show()
                elif a3=="clothes":
                    from PIL import Image
                    img=Image.open(r"C:\Users\DELL\OneDrive\Pictures\clothing.jpg")
                    img.show()
                else:
                    print("Not Avalable!")
            else:
                print("OK, No worries!")
        else:
            pass
        n=input("enter you want hostel facilities also: Yes/No")
        if n=="yes":
            l=["Ac","Cooler","Fan"]
            charges=[200000,150000,100000]
            d={"Rooms":l,"Charges":charges}
            import pandas as pd
            s=pd.DataFrame(d)
            print(s)
            n1=int(input("enter the position of which type of room you want: "))
            n2=s["Charges"][n1]
            print("Here these are the annual charges of Hostel")
        else:
            print("OK")
        fee=["EMI","Direct Pay"]
        d3={"Payment Method":fee}
        import pandas as pd
        s2=pd.DataFrame(d3)
        print(s2)
        p=int(input("enter the position of how you pay: "))
        if p==0:
            print("Please you can go to finance official to start your emi")
        elif p==1:
            d=df["Fees"][m]
            a4=input("Do you take conveyance facility: Yes/No").lower()
            if a4=="yes":
                p=df1["Charges per Km"]
                c=p*b1
                from colorama import Fore,Back,Style
                print(Fore.RED,Back.YELLOW,Style.BRIGHT,"Your Total Tution fees is",d)
                print("Your Total Conveyance charges is",c)
                total=d+c
                print("Your total amount you have to pay is",total)
                import cv2 as cv
                img=cv.imread(r"C:\Users\DELL\OneDrive\Pictures\scanner.jpg")
                cv.imshow("Scanner",img)
                cv.waitKey(0)
            a5=input("enter do you take hostel: Yes/No").lower()
            if a5=="yes":
                n2=s["Charges"][n1]
                d=df["Fees"][m]
                from colorama import Fore,Back,Style
                print(Fore.RED,Back.YELLOW,Style.BRIGHT,"Your Total Tution fees is",d)
                print("Your Hostel Charges are",n2)
                total1=d+n2
                print("Your Total amount you have to pay is",total1)
                import cv2 as cv
                img=cv.imread(r"C:\Users\DELL\OneDrive\Pictures\scanner.jpg")
                cv.imshow("Scanner",img)
                cv.waitKey(0)
                print("Thank You for taking Admission")
        else:
            print("Invalid")

# %%
obj=University()
key=input("Enter you want to do graduation or postgraduation: ").lower()
if key=="graduation":
    print(obj.graduation())
elif key=="postgraduation":
    print(obj.postgraduation())
# Out:
#    WELCOME TO VIVEKANAND GLOBAL UNIVERSITY
# Here you can do Following:
#
#  Graduation
#
#  Postgraduation
# Enter you want to do graduation or postgraduation:  graduation
#   Courses    Fees  Duration_Years
# 0     BBA  300000               3
# 1     BCA  280000               3
# 2   Btech  310000               4
# 3   B.COM  350000               3
# enter the position of course you want to enroll in:  1
# Here we have different different activities also, big events,fun games,social clubs
# Do you want to see any overview of events that previously occured: Yes/No yes
# Do you want campus tour: Yes/No yes
# enter you want conveyance facilities also:Yes/No  no
# Do you want to join any of the welfare club: Yes/No yes
# Here is the list of the club you can join any of them! Food for poor club
# Here is the list of the club you can join any of them! clothes for poor club
# Here is the list of the club you can join any of them! Free Health checkup club
# ...
